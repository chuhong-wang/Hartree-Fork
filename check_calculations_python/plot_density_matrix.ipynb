# %%
import numpy as np 
import matplotlib.pyplot as plt
input_str = """     1.04432    -0.190657  2.89829e-17    0.0804565 -2.43278e-16    -0.034688    -0.034688
   -0.190657     0.869842  3.58656e-16     -0.34784  1.22813e-15    0.0313577    0.0313577
 2.89829e-17  3.58656e-16     0.392584  2.05476e-16 -1.46834e-15     0.274076    -0.274076
   0.0804565     -0.34784  2.05476e-16     0.583079   1.1752e-15       0.2412       0.2412
-2.43278e-16  1.22813e-15 -1.46834e-15   1.1752e-15            1  -1.5166e-16 -2.05785e-15
   -0.034688    0.0313577     0.274076       0.2412  -1.5166e-16     0.338397   -0.0442854
   -0.034688    0.0313577    -0.274076       0.2412 -2.05785e-15   -0.0442854     0.338397"""

vals = input_str.split("\n")
vals = [it.split() for it in vals]


heatmap_data = np.zeros((len(vals), len(vals[0])))
for i in range(len(vals)):
    for j in range(len(vals[0])):
        heatmap_data[i,j] = vals[i][j]

cmap = plt.cm.RdBu_r
plt.imshow(heatmap_data, cmap=cmap, aspect='auto') # auto adjusted colorbar range to [min, max]
plt.colorbar(label='density value')

# %%
input_str = """1.06501    -0.285217  2.00739e-16   -0.0195534 -1.13037e-17    0.0334496    0.0334496
   -0.285217      1.24897 -9.96578e-16     0.113559  1.08661e-16    -0.144281    -0.144281
 2.00739e-16 -9.96578e-16      1.12587  1.00016e-17  -6.1561e-17    -0.146132     0.146132
  -0.0195534     0.113559  1.00016e-17      1.06606  4.63692e-17   -0.0993583   -0.0993583
-1.13037e-17  1.08661e-16  -6.1561e-17  4.63692e-17            1 -1.20081e-16 -2.46851e-16
   0.0334496    -0.144281    -0.146132   -0.0993583 -1.20081e-16    0.0426802   0.00474601
   0.0334496    -0.144281     0.146132   -0.0993583 -2.46851e-16   0.00474601    0.0426802"""

vals = input_str.split("\n")
vals = [it.split() for it in vals]


heatmap_data = np.zeros((len(vals), len(vals[0])))
for i in range(len(vals)):
    for j in range(len(vals[0])):
        heatmap_data[i,j] = vals[i][j]

cmap = plt.cm.RdBu_r
plt.imshow(heatmap_data, cmap=cmap, aspect='auto') # auto adjusted colorbar range to [min, max]
plt.colorbar(label='density value')
