# %%
import numpy as np 
import matplotlib.pyplot as plt
input_str = """1.01586    -0.393271  -0.00143266   0.00553169 -0.000262742     0.198156     0.193584      0.19211     0.197142
   -0.393271      2.87185   0.00158197  -0.00610525  0.000295619     -1.08471      -1.0774     -1.07504     -1.08309
 -0.00143266   0.00158197     0.852405  0.000650508  -0.00661016    -0.619118    -0.616223     0.617396      0.62112
  0.00553169  -0.00610525  0.000650508     0.849128   0.00177147     0.614657      -0.6212    -0.619885     0.614171
-0.000262742  0.000295619  -0.00661016   0.00177147     0.930077     0.640982    -0.637147      0.63648    -0.639728
    0.198156     -1.08471    -0.619118     0.614657     0.640982      1.73654   -0.0310384   -0.0505933    -0.032912
    0.193584      -1.0774    -0.616223      -0.6212    -0.637147   -0.0310384       1.7495    -0.026297   -0.0508972
     0.19211     -1.07504     0.617396    -0.619885      0.63648   -0.0505933    -0.026297      1.75371   -0.0293284
    0.197142     -1.08309      0.62112     0.614171    -0.639728    -0.032912   -0.0508972   -0.0293284      1.73941"""

vals = input_str.split("\n")
vals = [it.split() for it in vals]


heatmap_data = np.zeros((len(vals), len(vals[0])))
for i in range(len(vals)):
    for j in range(len(vals[0])):
        heatmap_data[i,j] = vals[i][j]

cmap = plt.cm.RdBu_r
plt.imshow(heatmap_data, cmap=cmap, aspect='auto') # auto adjusted colorbar range to [min, max]
plt.colorbar(label='density value')

# %%
input_str = """1.01517    -0.035661 -7.97926e-17 -2.56502e-16  2.83645e-16   -0.0645877   -0.0645877   -0.0645877   -0.0645877
   -0.035661     0.261782 -9.24068e-17  1.45275e-15  -8.4084e-16     0.114873     0.114873     0.114873     0.114873
-7.97926e-17 -9.24068e-17     0.344756  1.53409e-15 -1.91552e-15     0.171682     0.171682    -0.171682    -0.171682
-2.56502e-16  1.45275e-15  1.53409e-15     0.344756 -4.61822e-16    -0.171682     0.171682     0.171682    -0.171682
 2.83645e-16  -8.4084e-16 -1.91552e-15 -4.61822e-16     0.344756    -0.171682     0.171682    -0.171682     0.171682
  -0.0645877     0.114873     0.171682    -0.171682    -0.171682      0.30926   -0.0327157   -0.0327157   -0.0327157
  -0.0645877     0.114873     0.171682     0.171682     0.171682   -0.0327157      0.30926   -0.0327157   -0.0327157
  -0.0645877     0.114873    -0.171682     0.171682    -0.171682   -0.0327157   -0.0327157      0.30926   -0.0327157
  -0.0645877     0.114873    -0.171682    -0.171682     0.171682   -0.0327157   -0.0327157   -0.0327157      0.30926"""

vals = input_str.split("\n")
vals = [it.split() for it in vals]


heatmap_data = np.zeros((len(vals), len(vals[0])))
for i in range(len(vals)):
    for j in range(len(vals[0])):
        heatmap_data[i,j] = vals[i][j]

cmap = plt.cm.RdBu_r
plt.imshow(heatmap_data, cmap=cmap, aspect='auto') # auto adjusted colorbar range to [min, max]
plt.colorbar(label='density value')
